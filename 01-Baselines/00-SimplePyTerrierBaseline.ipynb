# %% [markdown]
# # TREC CrisisFACTs Track 2022 Tutorial
#
# This notebook illustrates how to download the TREC 2022 CrisisFACTs event streams along with the information needs for each one.

# %% [markdown]
# ## Downloading the Track Data
#
# Below, we walk you through the steps for downloading the CrisisFACTS data using the `ir_datasets` package.
#
# After downloading, we demonstrate converting this data into a Pandas DataFrame for quick inspect of the content associated with a given event-day pair.

# %% [markdown]
# <hr>
#
#
# **Part 1: Installing Needed Packages**
#
# Before we can get the data, we need to install some packages to handle the download process. In particular, we are going to install one main package:
#
# *   ir_datasets (https://github.com/allenai/ir_datasets): A python package that provides a common interface to many IR ad-hoc ranking benchmarks, training datasets, etc. We can use this to download the raw event streams and information needs for each.

# %%
# !pip install --upgrade git+https://github.com/allenai/ir_datasets.git@crisisfacts # install ir_datasets (crisisfacts branch)
# Out:
# Collecting git+https://github.com/allenai/ir_datasets.git@crisisfacts
#   Cloning https://github.com/allenai/ir_datasets.git (to revision crisisfacts) to /tmp/pip-req-build-hx00m2es
#   Running command git clone --filter=blob:none --quiet https://github.com/allenai/ir_datasets.git /tmp/pip-req-build-hx00m2es
#   Running command git checkout -b crisisfacts --track origin/crisisfacts
#   Switched to a new branch 'crisisfacts'
#   Branch 'crisisfacts' set up to track remote branch 'crisisfacts' from 'origin'.
#   Resolved https://github.com/allenai/ir_datasets.git to commit e2359e24c9546e2a62284cd1aec6138295bb5ec5
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir-datasets==0.5.2) (4.11.1)
# Requirement already satisfied: lxml>=4.5.2 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir-datasets==0.5.2) (4.9.1)
# Requirement already satisfied: numpy>=1.18.1 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir-datasets==0.5.2) (1.21.5)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir-datasets==0.5.2) (5.4.1)
# Requirement already satisfied: requests>=2.22.0 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir-datasets==0.5.2) (2.28.1)
# Requirement already satisfied: tqdm>=4.38.0 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir-datasets==0.5.2) (4.64.1)
# Collecting trec-car-tools>=2.5.4
#   Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Requirement already satisfied: lz4>=3.1.1 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir-datasets==0.5.2) (3.1.3)
# Collecting warc3-wet>=0.2.3
#   Downloading warc3_wet-0.2.3-py3-none-any.whl (13 kB)
# Collecting warc3-wet-clueweb09>=0.2.5
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting zlib-state>=0.1.3
#   Downloading zlib_state-0.1.5-cp39-cp39-manylinux2010_x86_64.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 12.2 MB/s eta 0:00:00
# Collecting ijson>=3.1.3
#   Downloading ijson-3.2.0.post0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 21.3 MB/s eta 0:00:00
# Collecting pyautocorpus>=0.1.1
#   Downloading pyautocorpus-0.1.9-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 35.0 MB/s eta 0:00:00
# Collecting unlzw3>=0.2.1
#   Downloading unlzw3-0.2.2-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: soupsieve>1.2 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.4.1->ir-datasets==0.5.2) (2.3.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from requests>=2.22.0->ir-datasets==0.5.2) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from requests>=2.22.0->ir-datasets==0.5.2) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from requests>=2.22.0->ir-datasets==0.5.2) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from requests>=2.22.0->ir-datasets==0.5.2) (3.3)
# Collecting cbor>=1.0.0
#   Downloading cbor-1.0.0.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ir-datasets, warc3-wet-clueweb09, cbor
#   Building wheel for ir-datasets (setup.py) ... done
#   Created wheel for ir-datasets: filename=ir_datasets-0.5.2-py3-none-any.whl size=304039 sha256=7348eadbea3249b4f274ab75a559285965d51b86191b3b5178465226fd32e22a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-29nbqeyv/wheels/84/05/db/c12b0fef15c7cb0e760e931dc6c9c2706e5ecf452f0c5230af
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18920 sha256=e3786713ed7ea883ed99a27bfef8f2d687b8b6be1f2153a30a97a1aa4aaeec69
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/7f/22/ed/a11944d7fdf4e94c4206a3f760d385122a4d34d8acc12f71a3
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-py3-none-any.whl size=10031 sha256=8c1f1b7b4d9b74ecfa8cd5adb23cdf1a53f2cee5f38c7d95f8bc635769052128
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/ec/10/03/a281e0682ddd4b310431fb25d1a4f53987105267cf46c417f3
# Successfully built ir-datasets warc3-wet-clueweb09 cbor
# Installing collected packages: warc3-wet-clueweb09, warc3-wet, ijson, cbor, zlib-state, unlzw3, trec-car-tools, pyautocorpus, ir-datasets
# Successfully installed cbor-1.0.0 ijson-3.2.0.post0 ir-datasets-0.5.2 pyautocorpus-0.1.9 trec-car-tools-2.6 unlzw3-0.2.2 warc3-wet-0.2.3 warc3-wet-clueweb09-0.2.5 zlib-state-0.1.5

# %% [markdown]
# <hr>
#
#
#
# **Part 2: Initalizing Your Credentials**
#
# When you want to download part of the CrisisFACTs dataset we require that you provide a set of contact details. The reason for this is two-fold: 1) the terms of service from some of the platforms (like Twitter) from which we have sourced data require us to do so, and 2) it allows us to collect statistics on how many people are making use of the data we provide.
#
# **GDPR Statement**: By downloading the CrisisFACTs datasets, you agree to the University of Glasgow processing your personal data, as defined by the EU General Data Protection Regulation (GDPR) - your name and email in this case. Queries about data processing and access/deletion requests should be sent to [me via email](http://www.dcs.gla.ac.uk/~richardm/Home/Contact.html). We will store your data for as long as the track is on-going and up-to 2 years beyond that. I may contact you using the details provided to notify you about changes in the datasets or track, to provide information or ask you questions about your participation or otherwise contact you about topics relevant to emergency management. We may collate statistics from the provided information that will be published, but we will not release individual names or email addresses.
#
# Rather than entering these details every time you request the dataset, its more effcient to set this once up-front, so fill in your details below:

# %%
credentials = {
    "institution": "<University/Agency Name>", # University, Company or Public Agency Name
    "contactname": "<Your Name>", # Your Name
    "email": "<Your Email>", # A contact email address
    "institutiontype": "<Research | Industry | Public Sector>" # Either 'Research', 'Industry', or 'Public Sector'
}

# Write this to a file so it can be read when needed
import json
import os

home_dir = os.path.expanduser('~')

# !mkdir -p ~/.ir_datasets/auth/
with open(home_dir + '/.ir_datasets/auth/crisisfacts.json', 'w') as f:
    json.dump(credentials, f)

# %% [markdown]
# <hr>
#
# **Part 3: Understanding the structure of the CrisisFACTs Dataset**
#
# The CrisisFACTs dataset is divided into events, representing real-world crises. Each event is given an identifier, e.g. 'CrisisFACTS-001' is the Lilac Wildfire from 2017. We sometimes refer to the event number or 'eventNo', this is the last three digits of the event identifier, e.g. '001'. There are 8 events for CrisisFACTs 2022:

# %%
# Event numbers as a list
eventNoList = [
        "001", # Lilac Wildfire 2017
        "002", # Cranston Wildfire 2018
        "003", # Holy Wildfire 2018
        "004", # Hurricane Florence 2018
        "005", # 2018 Maryland Flood
        "006", # Saddleridge Wildfire 2019
        "007", # Hurricane Laura 2020
        "008", # Hurricane Sally 2020
        "009", # Beirut Explosion, 2020
        "010", # Houston Explosion, 2020
        "011", # Rutherford TN Floods, 2020
        "012", # TN Derecho, 2020
        "013", # Edenville Dam Fail, 2020
        "014", # Hurricane Dorian, 2019
        "015", # Kincade Wildfire, 2019
        "016", # Easter Tornado Outbreak, 2020
        "017", # Tornado Outbreak, 2020 Apr
        "018", # Tornado Outbreak, 2020 March
]

# %% [markdown]
# Each event has a duration, i.e. it lasts for a number of days. In the CrisisFACTs track, you need to produce a timeline summary for each day for a set of events. You can get the list of days for an event as shown below (example is for event "001", i.e. the Lilac Wildfire 2017):

# %%
import requests

# Gets the list of days for a specified event number, e.g. '001'
def getDaysForEventNo(eventNo):

    # We will download a file containing the day list for an event
    url = "http://trecis.org/CrisisFACTs/CrisisFACTS-"+eventNo+".requests.json"

    # Download the list and parse as JSON
    dayList = requests.get(url).json()

    # Print each day
    # Note each day object contains the following fields
    #   {
    #      "eventID" : "CrisisFACTS-001",
    #      "requestID" : "CrisisFACTS-001-r3",
    #      "dateString" : "2017-12-07",
    #      "startUnixTimestamp" : 1512604800,
    #      "endUnixTimestamp" : 1512691199
    #   }

    return dayList

for day in getDaysForEventNo(eventNoList[0]):
    print(day["dateString"])
# Out:
# 2017-12-07
# 2017-12-08
# 2017-12-09
# 2017-12-10
# 2017-12-11
# 2017-12-12
# 2017-12-13
# 2017-12-14
# 2017-12-15

# %% [markdown]
# Now that we know what the request strings for each event and day are, we can download for the associated stream for each via ir_datasets:

# %% [markdown]
# **Part 1. Installing Packages**
#
# Search engines are a core part of the online information space, and much work has gone into making this technology accessible and easy to develop. A major package in this space that is designed to facilitate experimentation with search and information-retrieval methods is `Terrier` and its related Python bindings. To use this library, we install the following packages:
#
# *   pyTerrier (https://pyterrier.readthedocs.io/en/latest/): pyTerrier is a python wrapper around the Terrier IR Platform (a search engine in-a-box). We will use this to produce a searchable index for each day during a crisis event, so we can retrieve (hopefully) relevant content for different information needs.

# %%
# !pip install --upgrade python-terrier # install pyTerrier
# Out:
# Collecting python-terrier
#   Downloading python-terrier-0.9.2.tar.gz (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 13.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from python-terrier) (1.21.5)
# Requirement already satisfied: pandas in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from python-terrier) (1.4.4)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from python-terrier) (4.64.1)
# Collecting pyjnius>=1.4.2
#   Downloading pyjnius-1.5.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 40.9 MB/s eta 0:00:0000:01
# Collecting matchpy
#   Downloading matchpy-0.5.5-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from python-terrier) (1.0.2)
# Collecting deprecated
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting chest
#   Downloading chest-0.2.3.tar.gz (9.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from python-terrier) (1.9.1)
# Requirement already satisfied: requests in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from python-terrier) (2.28.1)
# Requirement already satisfied: joblib in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from python-terrier) (1.1.0)
# Collecting nptyping==1.4.4
#   Downloading nptyping-1.4.4-py3-none-any.whl (31 kB)
# Collecting more_itertools
#   Downloading more_itertools-9.1.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.2/54.2 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: ir_datasets>=0.3.2 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from python-terrier) (0.5.2)
# Requirement already satisfied: jinja2 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from python-terrier) (2.11.3)
# Requirement already satisfied: statsmodels in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from python-terrier) (0.13.2)
# Collecting ir_measures>=0.3.1
#   Downloading ir_measures-0.3.1.tar.gz (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.5/46.5 kB 7.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: dill in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from python-terrier) (0.3.4)
# Collecting pytrec_eval_terrier>=0.5.3
#   Downloading pytrec_eval_terrier-0.5.5-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 kB 37.1 MB/s eta 0:00:00
# Collecting typish>=1.7.0
#   Downloading typish-1.9.3-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: pyautocorpus>=0.1.1 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir_datasets>=0.3.2->python-terrier) (0.1.9)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir_datasets>=0.3.2->python-terrier) (0.2.5)
# Requirement already satisfied: ijson>=3.1.3 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir_datasets>=0.3.2->python-terrier) (3.2.0.post0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir_datasets>=0.3.2->python-terrier) (4.11.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir_datasets>=0.3.2->python-terrier) (5.4.1)
# Requirement already satisfied: lz4>=3.1.1 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir_datasets>=0.3.2->python-terrier) (3.1.3)
# Requirement already satisfied: warc3-wet>=0.2.3 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir_datasets>=0.3.2->python-terrier) (0.2.3)
# Requirement already satisfied: zlib-state>=0.1.3 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir_datasets>=0.3.2->python-terrier) (0.1.5)
# Requirement already satisfied: lxml>=4.5.2 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir_datasets>=0.3.2->python-terrier) (4.9.1)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir_datasets>=0.3.2->python-terrier) (2.6)
# Requirement already satisfied: unlzw3>=0.2.1 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from ir_datasets>=0.3.2->python-terrier) (0.2.2)
# Collecting cwl-eval>=1.0.10
#   Downloading cwl-eval-1.0.12.tar.gz (31 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from requests->python-terrier) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from requests->python-terrier) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from requests->python-terrier) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from requests->python-terrier) (2022.9.14)
# Requirement already satisfied: heapdict in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from deprecated->python-terrier) (1.14.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from jinja2->python-terrier) (2.0.1)
# Collecting multiset<3.0,>=2.0
#   Downloading multiset-2.1.1-py2.py3-none-any.whl (8.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from pandas->python-terrier) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from scikit-learn->python-terrier) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from statsmodels->python-terrier) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from statsmodels->python-terrier) (0.5.2)
# Requirement already satisfied: soupsieve>1.2 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from beautifulsoup4>=4.4.1->ir_datasets>=0.3.2->python-terrier) (2.3.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from packaging>=21.3->statsmodels->python-terrier) (3.0.9)
# Requirement already satisfied: six in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels->python-terrier) (1.16.0)
# Requirement already satisfied: cbor>=1.0.0 in /home/ubuntu/anaconda3/lib/python3.9/site-packages (from trec-car-tools>=2.5.4->ir_datasets>=0.3.2->python-terrier) (1.0.0)
# Building wheels for collected packages: python-terrier, ir_measures, chest, wget, cwl-eval
#   Building wheel for python-terrier (setup.py) ... done
#   Created wheel for python-terrier: filename=python_terrier-0.9.2-py3-none-any.whl size=112259 sha256=c36c04bdeff91f8f02cf22223d5c87d1b5005edf3827ddb6b55b1e0477d85a2a
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/0c/4d/40/9d00263171f82fe37049a60e70a88279ce025c0229110153d4
#   Building wheel for ir_measures (setup.py) ... done
#   Created wheel for ir_measures: filename=ir_measures-0.3.1-py3-none-any.whl size=60166 sha256=877a358959cd4223e99b9b1ad343a0879805fae9eb22d801372d4c1fd25d0a53
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/00/fa/7d/0ba22fce7d11d69df68c31b7c247fbbb28fe2d4c610f8c653f
#   Building wheel for chest (setup.py) ... done
#   Created wheel for chest: filename=chest-0.2.3-py3-none-any.whl size=7612 sha256=424903937d1c31f07e9acde9a027e1dd61c0848745eeae4aa4090e0e3aed20a8
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/ce/05/8e/2ecd3728ed5d938ee57161c8acf2ee74f55f894964bb3d31ef
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=cb1a96b90124066acb1bd62b0f0b570c46f82c82d4d3ce7e4e3c8b7bfa497ff8
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/04/5f/3e/46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
#   Building wheel for cwl-eval (setup.py) ... done
#   Created wheel for cwl-eval: filename=cwl_eval-1.0.12-py3-none-any.whl size=38068 sha256=903972b81eeb0b0cb955a25455766b15745acd49e577dacff639ed22a603f233
#   Stored in directory: /home/ubuntu/.cache/pip/wheels/0e/52/dc/9d448ff093ccae9b248a41b265d31e2c930eea2d0e84aa29e0
# Successfully built python-terrier ir_measures chest wget cwl-eval
# Installing collected packages: wget, typish, pyjnius, multiset, pytrec_eval_terrier, nptyping, more_itertools, matchpy, deprecated, cwl-eval, chest, ir_measures, python-terrier
# Successfully installed chest-0.2.3 cwl-eval-1.0.12 deprecated-1.2.13 ir_measures-0.3.1 matchpy-0.5.5 more_itertools-9.1.0 multiset-2.1.1 nptyping-1.4.4 pyjnius-1.5.0 python-terrier-0.9.2 pytrec_eval_terrier-0.5.5 typish-1.9.3 wget-3.2

# %% [markdown]
# # Simple query-based baseline

# %%
eventsMeta = {}

for eventNo in eventNoList: # for each event
    print("Event "+eventNo)
    
    dailyInfo = getDaysForEventNo(eventNo) # get the list of days
    eventsMeta[eventNo]= dailyInfo
    for day in dailyInfo: # for each day
        print("  crisisfacts/"+eventNo+"/"+day["dateString"], "-->", day["requestID"]) # construct the request string

#   crisisfacts/013/2020-05-28 --> CrisisFACTS-013-r5
#   crisisfacts/013/2020-05-29 --> CrisisFACTS-013-r6
#
# Event 014
#   crisisfacts/014/2019-08-29 --> CrisisFACTS-014-r0
#   crisisfacts/014/2019-08-30 --> CrisisFACTS-014-r1
#   crisisfacts/014/2019-08-31 --> CrisisFACTS-014-r2
#   crisisfacts/014/2019-09-01 --> CrisisFACTS-014-r3
#   crisisfacts/014/2019-09-02 --> CrisisFACTS-014-r4
#   crisisfacts/014/2019-09-03 --> CrisisFACTS-014-r5
#   crisisfacts/014/2019-09-04 --> CrisisFACTS-014-r6
#
# Event 015
#   crisisfacts/015/2019-10-25 --> CrisisFACTS-015-r0
#   crisisfacts/015/2019-10-26 --> CrisisFACTS-015-r1
#   crisisfacts/015/2019-10-27 --> CrisisFACTS-015-r2
#   crisisfacts/015/2019-10-28 --> CrisisFACTS-015-r3
#   crisisfacts/015/2019-10-29 --> CrisisFACTS-015-r4
#   crisisfacts/015/2019-10-30 --> CrisisFACTS-015-r5
#   crisisfacts/015/2019-10-31 --> CrisisFACTS-015-r6
#
# Event 016
#   crisisfacts/016/2020-04-12 --> CrisisFACTS-016-r0
#   crisisfacts/016/2020-04-13 --> CrisisFACTS-016-r1
#   crisisfacts/016/2020-04-14 --> CrisisFACTS-016-r2
#   crisisfacts/016/2020-04-15 --> CrisisFACTS-016-r3
#   crisisfacts/016/2020-04-16 --> CrisisFACTS-016-r4
#
# Event 017
#   crisisfacts/017/2020-04-21 --> CrisisFACTS-017-r0
#   crisisfacts/017/2020-04-22 --> CrisisFACTS-017-r1
#   crisisfacts/017/2020-04-23 --> CrisisFACTS-017-r2
#   crisisfacts/017/2020-04-24 --> CrisisFACTS-017-r3
#   crisisfacts/017/2020-04-25 --> CrisisFACTS-017-r4
#   crisisfacts/017/2020-04-26 --> CrisisFACTS-017-r5
#
# Event 018
#   crisisfacts/018/2020-03-02 --> CrisisFACTS-018-r0
#   crisisfacts/018/2020-03-03 --> CrisisFACTS-018-r1
#   crisisfacts/018/2020-03-04 --> CrisisFACTS-018-r2
#   crisisfacts/018/2020-03-05 --> CrisisFACTS-018-r3
#   crisisfacts/018/2020-03-06 --> CrisisFACTS-018-r4
#   crisisfacts/018/2020-03-07 --> CrisisFACTS-018-r5

# %%
import pandas as pd
import numpy as np
import pyterrier as pt

import ir_datasets

# %%
def get_retriever(datasetID):
    # Initalize pyTerrier if not started
    if not pt.started():
        pt.init()

    # Ask pyTerrier to download the dataset, the 'irds:' header tells pyTerrier to use ir_datasets as the data source
    pyTerrierDataset = pt.get_dataset(f'irds:{datasetID}')
    # To create the index, we use an 'indexer', this interates over the documents in the collection and adds them to the index
    # The paramters of this call are:
    #  Index Storage Path: "None" (some index types write to disk, this would be the directory to write to)
    #  Index Type: type=pt.index.IndexingType(3) (Type 3 is a Memory Index)
    #  Meta Index Fields: meta=['docno', 'text'] (The index also can store raw fields so they can be attached to the search results, this specifies what fields to store)
    #  Meta Index Lengths: meta_lengths=[40, 200] (pyTerrier allocates a fixed amount of storage space per field, how many characters should this be?)
    indexer = pt.IterDictIndexer(
        "None", 
        type=pt.index.IndexingType(3), 
        meta=['docno', 'text'], 
        meta_lengths=[40, 200],
    )

    # Trigger the indexing process
    index = indexer.index(pyTerrierDataset.get_corpus_iter())
    retriever = pt.BatchRetrieve(
        index, 
        wmodel="DFReeKLIM", 
        metadata=["docno", "text"],
    )
    return retriever

def  get_quries_hits(retriever, queries):
    
    event_queries={}
    event_scores={}
    
    for index, query in queries.iterrows():
        results = pd.DataFrame(retriever.search(query['indicative_terms']))
        
        for ind, result in results.iterrows():
            if result['docno'] in event_queries:
                event_queries[result['docno']].append(query['query_id'])
                event_scores[result['docno']].append(result['score'])
            else:
                event_queries[result['docno']]=[query['query_id']]
                event_scores[result['docno']]=[result['score']]
    
    return event_queries,event_scores

# %%
# Build the document cache for each CrisisFACTS event-day
#. request. All data goes to the `ir_datasets/crisisfacts` directory,
#. which on Unix-type machines is `~/.ir_datasets/crisisfacts/`
for eventId,dailyInfo in eventsMeta.items():

    for thisDay in dailyInfo:
        
        requestID = thisDay["requestID"]
        ir_dataset_id = "crisisfacts/%s/%s" % (eventId, thisDay["dateString"])        
        
        dataset = ir_datasets.load(ir_dataset_id)
        print(dataset.dataset_id())
        
        itemsAsDataFrame = pd.DataFrame(dataset.docs_iter())
        print("\tDataset Size:", itemsAsDataFrame.shape[0])
        
        queries = pd.DataFrame(dataset.queries_iter())
        print("\tQuery Count:", queries.shape[0])
        
        # Both of these should be true. If you get an error here, 
        #. it suggests a bug popped up during data download. 
        #. Try re-running this cell.
        assert itemsAsDataFrame.shape[0] > 0
        assert queries.shape[0] > 0
# Out:
# crisisfacts/001/2017-12-07
# 	Dataset Size: 7288
# 	Query Count: 52
# crisisfacts/001/2017-12-08
# 	Dataset Size: 19231
# 	Query Count: 52
# crisisfacts/001/2017-12-09
# 	Dataset Size: 5839
# 	Query Count: 52
# crisisfacts/001/2017-12-10
# 	Dataset Size: 4407
# 	Query Count: 52
# crisisfacts/001/2017-12-11
# 	Dataset Size: 3394
# 	Query Count: 52
# crisisfacts/001/2017-12-12
# 	Dataset Size: 2805
# 	Query Count: 52
# crisisfacts/001/2017-12-13
# 	Dataset Size: 2658
# 	Query Count: 52
# crisisfacts/001/2017-12-14
# 	Dataset Size: 2728
# 	Query Count: 52
# crisisfacts/001/2017-12-15
# 	Dataset Size: 2665
# 	Query Count: 52
# crisisfacts/002/2018-07-25
# 	Dataset Size: 5056
# 	Query Count: 52
# crisisfacts/002/2018-07-26
# 	Dataset Size: 7866
# 	Query Count: 52
# crisisfacts/002/2018-07-27
# 	Dataset Size: 7433
# 	Query Count: 52
# crisisfacts/002/2018-07-28
# 	Dataset Size: 5238
# 	Query Count: 52
# crisisfacts/002/2018-07-29
# 	Dataset Size: 4691
# 	Query Count: 52
# crisisfacts/002/2018-07-30
# 	Dataset Size: 251
# 	Query Count: 52
# crisisfacts/003/2018-08-06
# crisisfacts/014/2019-08-29
# 	Dataset Size: 8000
# 	Query Count: 51
# crisisfacts/014/2019-08-30
# 	Dataset Size: 34000
# 	Query Count: 51
# crisisfacts/014/2019-08-31
# 	Dataset Size: 31000
# 	Query Count: 51
# crisisfacts/014/2019-09-01
# 	Dataset Size: 10000
# 	Query Count: 51
# crisisfacts/014/2019-09-02
# 	Dataset Size: 29000
# 	Query Count: 51
# crisisfacts/014/2019-09-03
# 	Dataset Size: 20000
# 	Query Count: 51
# crisisfacts/014/2019-09-04
# 	Dataset Size: 12000
# 	Query Count: 51
# crisisfacts/015/2019-10-25
# 	Dataset Size: 12000
# 	Query Count: 52
# crisisfacts/015/2019-10-26
# 	Dataset Size: 1000
# 	Query Count: 52
# crisisfacts/015/2019-10-27
# 	Dataset Size: 26178
# 	Query Count: 52
# crisisfacts/015/2019-10-28
# 	Dataset Size: 1000
# 	Query Count: 52
# crisisfacts/015/2019-10-29
# 	Dataset Size: 4000
# 	Query Count: 52
# crisisfacts/015/2019-10-30
# 	Dataset Size: 7000
# 	Query Count: 52
# crisisfacts/015/2019-10-31
# 	Dataset Size: 3000
# 	Query Count: 52
# crisisfacts/016/2020-04-12
# 	Dataset Size: 54642
# 	Query Count: 51
# crisisfacts/016/2020-04-13
# 	Dataset Size: 14000
# 	Query Count: 51
# crisisfacts/016/2020-04-14
# 	Dataset Size: 22000
# 	Query Count: 51
# crisisfacts/016/2020-04-15
# 	Dataset Size: 4832
# 	Query Count: 51
# crisisfacts/016/2020-04-16
# 	Dataset Size: 53
# 	Query Count: 51
# crisisfacts/017/2020-04-21
# 	Dataset Size: 20900
# 	Query Count: 51
# crisisfacts/017/2020-04-22
# 	Dataset Size: 13000
# 	Query Count: 51
# crisisfacts/017/2020-04-23
# 	Dataset Size: 29506
# 	Query Count: 51
# crisisfacts/017/2020-04-24
# 	Dataset Size: 6000
# 	Query Count: 51
# crisisfacts/017/2020-04-25
# 	Dataset Size: 4000
# 	Query Count: 51
# crisisfacts/017/2020-04-26
# 	Dataset Size: 2108
# 	Query Count: 51
# crisisfacts/018/2020-03-02
# 	Dataset Size: 3000
# 	Query Count: 51
# crisisfacts/018/2020-03-03
# 	Dataset Size: 123416
# 	Query Count: 51
# crisisfacts/018/2020-03-04
# 	Dataset Size: 52566
# 	Query Count: 51
# crisisfacts/018/2020-03-05
# 	Dataset Size: 14918
# 	Query Count: 51
# crisisfacts/018/2020-03-06
# 	Dataset Size: 336
# 	Query Count: 51
# crisisfacts/018/2020-03-07
# 	Dataset Size: 77
# 	Query Count: 51

# %%
rows = []

for eventId,dailyInfo in eventsMeta.items():

    for thisDay in dailyInfo:
        
        requestID = thisDay["requestID"]
        ir_dataset_id = "crisisfacts/%s/%s" % (eventId, thisDay["dateString"])        
        
        # Should use the cached data we downloaded above
        dataset = ir_datasets.load(ir_dataset_id)        
        queries = pd.DataFrame(dataset.queries_iter())

        retriever = get_retriever(ir_dataset_id)
        event_queries, event_scores = get_quries_hits(retriever,queries)
        
        itemsAsDataFrame = pd.DataFrame(dataset.docs_iter())

        for key,value in event_scores.items():
            fact = itemsAsDataFrame.query(f"doc_id== '{key}'").iloc[0]
            
            rows.append({
                'requestID' : requestID, 
                'factText' : fact["text"], 
                'unixTimestamp' : fact["unix_timestamp"],
                "importance_count" : len(value),
                "importance_sum" : np.sum(value),
                "sources" : [key],
                "streamID" : key,
                "informationNeeds" : event_queries[key]
            })

output = pd.DataFrame(rows)
# Out:
# crisisfacts/001/2017-12-07 documents: 7288it [00:01, 6492.80it/s]
# 17:46:14.857 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/001/2017-12-08 documents: 19231it [00:04, 4506.85it/s]
# 17:46:35.551 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/001/2017-12-09 documents: 5839it [00:01, 5270.65it/s]
# 17:47:20.535 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/001/2017-12-10 documents: 4407it [00:00, 7515.32it/s]
# 17:47:28.354 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/001/2017-12-11 documents: 3394it [00:00, 8335.85it/s]
# 17:47:33.716 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/001/2017-12-12 documents: 2805it [00:00, 7850.02it/s]
# 17:47:37.799 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/001/2017-12-13 documents: 2658it [00:00, 9182.69it/s]
# 17:47:40.862 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/001/2017-12-14 documents: 2728it [00:00, 11050.82it/s]
# 17:47:43.239 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/001/2017-12-15 documents: 2665it [00:00, 6732.35it/s]
# 17:47:46.473 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/002/2018-07-25 documents: 5056it [00:00, 5296.69it/s]
# 17:47:49.616 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/002/2018-07-26 documents: 7866it [00:01, 6586.86it/s]
# 17:47:54.364 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/002/2018-07-27 documents: 7433it [00:00, 7481.62it/s]
# 17:48:03.564 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/002/2018-07-28 documents: 5238it [00:00, 8450.59it/s]
# 17:48:11.824 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/002/2018-07-29 documents: 4691it [00:00, 9237.29it/s]
# 17:48:17.282 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/002/2018-07-30 documents: 251it [00:00, 9681.89it/s]
# 17:48:21.515 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/003/2018-08-06 documents: 4402it [00:00, 10274.53it/s]
# 17:48:22.711 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/003/2018-08-07 documents: 5727it [00:00, 7191.29it/s]
# 17:48:26.470 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/003/2018-08-08 documents: 5925it [00:00, 6962.10it/s]
# 17:48:31.933 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/003/2018-08-09 documents: 5984it [00:00, 7885.32it/s]
# 17:48:37.805 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/003/2018-08-10 documents: 6233it [00:00, 7832.42it/s]
# 17:48:43.288 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/003/2018-08-12 documents: 4023it [00:00, 8759.50it/s]
# 17:48:48.942 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/003/2018-08-13 documents: 195it [00:00, 10939.17it/s]
# 17:48:51.045 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/004/2018-09-01 documents: 7959it [00:00, 19636.65it/s]
# 17:48:51.851 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/004/2018-09-04 documents: 503it [00:00, 16659.18it/s]
# 17:49:04.667 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/004/2018-09-05 documents: 1559it [00:00, 18428.32it/s]
# 17:49:05.317 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/004/2018-09-07 documents: 3329it [00:00, 22686.28it/s]
# 17:49:06.086 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/004/2018-09-08 documents: 6056it [00:00, 22378.00it/s]
# 17:49:08.559 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/004/2018-09-09 documents: 4000it [00:00, 22142.24it/s]
# 17:49:13.851 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/004/2018-09-10 documents: 38738it [00:02, 17758.02it/s]
# 17:49:19.276 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/004/2018-09-11 documents: 55465it [00:03, 15395.03it/s]
# 17:50:24.462 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts
[main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/015/2019-10-31 documents: 3000it [00:00, 11483.38it/s]
# 18:38:04.282 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/016/2020-04-12 documents: 54642it [00:09, 5649.88it/s]
# 18:38:17.270 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/016/2020-04-13 documents: 14000it [00:01, 9397.94it/s]
# 18:40:19.320 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/016/2020-04-14 documents: 22000it [00:03, 5721.30it/s]
# 18:40:49.942 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/016/2020-04-15 documents: 4832it [00:00, 5030.57it/s]
# 18:41:19.451 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/016/2020-04-16 documents: 53it [00:00, 9214.05it/s]
# 18:41:29.437 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/017/2020-04-21 documents: 20900it [00:03, 5777.18it/s]
# 18:41:33.917 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/017/2020-04-22 documents: 13000it [00:02, 6418.12it/s]
# 18:42:03.760 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/017/2020-04-23 documents: 29506it [00:05, 5614.48it/s]
# 18:42:26.377 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/017/2020-04-24 documents: 6000it [00:00, 9062.09it/s]
# 18:43:16.000 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/017/2020-04-25 documents: 4000it [00:00, 14182.78it/s]
# 18:43:24.404 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/017/2020-04-26 documents: 2108it [00:00, 5554.61it/s]
# 18:43:30.298 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/018/2020-03-02 documents: 3000it [00:00, 10666.54it/s]
# 18:43:32.914 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/018/2020-03-03 documents: 123416it [00:20, 5916.56it/s]
# 18:43:56.351 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/018/2020-03-04 documents: 52566it [00:05, 8888.73it/s]
# 18:47:23.520 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/018/2020-03-05 documents: 14918it [00:01, 13729.67it/s]
# 18:48:33.188 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/018/2020-03-06 documents: 336it [00:00, 26576.26it/s]
# 18:48:48.616 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.
# crisisfacts/018/2020-03-07 documents: 77it [00:00, 20217.94it/s]
# 18:48:49.116 [main] WARN org.terrier.querying.ApplyTermPipeline - The index has no termpipelines configuration, and no control configuration is found. Defaulting to global termpipelines configuration of 'Stopwords,PorterStemmer'. Set a termpipelines control to remove this warning.

# %%
output["importance_count"] = output["importance_count"] / output["importance_count"].max()
output["importance_sum"] = output["importance_sum"] / output["importance_sum"].max()

# %%
with open("./submission_v1.json", "w") as out_file:
    for idx,row in output\
        .drop(columns=["importance_sum"])\
        .rename(columns={"importance_count": "importance"})\
        .iterrows():
        
        out_file.write("%s\n" % json.dumps(dict(row)))

with open("./submission_v2.json", "w") as out_file:
    for idx,row in output\
        .drop(columns=["importance_count"])\
        .rename(columns={"importance_sum": "importance"})\
        .iterrows():
        
        out_file.write("%s\n" % json.dumps(dict(row)))

# %%
with open("./submission_v1.json", "r") as in_file:
    submission_rows = [json.loads(line) for line in in_file]
submission_df = pd.DataFrame(submission_rows)

# %%
top_k = 64

for reqId, group in submission_df.groupby("requestID"):
    print(reqId, group.shape[0])
    
    summary = " ".join(group.sort_values(by="importance", ascending=False).head(top_k)["factText"])
    
    print(summary)
    
    break
# Out:
# CrisisFACTS-001-r10 654
